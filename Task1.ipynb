# %% [markdown]
# # Task 1
# #### Week 1 (Learning Period Synapse)
# ###### pandas, numpy, matplotlib

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## 1. Import pandas, numpy and matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. load the data
# <br> load the titanic dataset in a pandas dataframe <br> (download dataset from https://www.kaggle.com/c/titanic/data and store it in a folder called <b>"syanpse_w1"</b> in the root of your drive) <br>
# Note that you have to download the train and test csv files seperately

# %%
train_path = "/content/gdrive/MyDrive/synapse_w1/train.csv"
test_path = "/content/gdrive/My Drive/synapse_w1/test.csv"

#write code to load train.csv and test.csv in dataframes
train_df = pd.read_csv(train_path)
test_df = pd.read_csv(test_path)
train_df
test_df
# Out:
#      PassengerId  Pclass  ... Cabin Embarked
# 0            892       3  ...   NaN        Q
# 1            893       3  ...   NaN        S
# 2            894       2  ...   NaN        Q
# 3            895       3  ...   NaN        S
# 4            896       3  ...   NaN        S
# ..           ...     ...  ...   ...      ...
# 413         1305       3  ...   NaN        S
# 414         1306       1  ...  C105        C
# 415         1307       3  ...   NaN        S
# 416         1308       3  ...   NaN        S
# 417         1309       3  ...   NaN        C
#
# [418 rows x 11 columns]

# %%
#write code to show first five data entries of both dataframes
train_df.head(5)
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
test_df.head(5)
# Out:
#    PassengerId  Pclass  ... Cabin Embarked
# 0          892       3  ...   NaN        Q
# 1          893       3  ...   NaN        S
# 2          894       2  ...   NaN        Q
# 3          895       3  ...   NaN        S
# 4          896       3  ...   NaN        S
#
# [5 rows x 11 columns]

# %% [markdown]
# ## 3. Exploratory Data Analysis
# Exploratory data analysis is a very important part of ML as it helps you understand the data you are dealing with <br>
# <br>
# (we will be working on the train dataframe in this task)

# %% [markdown]
# ### 3.a. overview of the dataset

# %% [markdown]
#  - write code to list the columns in your dataframe (each column on new line as visibility is important)

# %%
#write code here
print("for train dataset:")
train_list=list(train_df)
for col1_name in train_list: 
    print(col1_name)
print("for test dataset:")
test_list=list(test_df)
for col2_name in test_list:  
    print(col2_name)
# Out:
# for train dataset:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked
# for test dataset:
# PassengerId
# Pclass
# Name
# Sex
# Age
# SibSp
# Parch
# Ticket
# Fare
# Cabin
# Embarked

# %% [markdown]
#  - write a function that returns the number of rows and columns in the dataset

# %%
#write code here (print values as well)

def number(take):
  rows=len(take)
  columns=len(take.columns)
  return rows,columns

print("number of rows, columns for train dataset:")
number(train_df)
#print("number of rows for test dataset:")
#number(test_df)
# Out:
# number of rows, columns for train dataset:
# (891, 12)

# %% [markdown]
#  - use the info() method of pandas dataframe to print the info related to the dataframe

# %%
# write code here
train_df.info()
print("---------------------------------------------")
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# ---------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
#  - use the describe() method of pandas dataframe to print the statistical description of the dataset

# %%
#write code here
train_df.describe()
#print("--------------------------------------------")
#test_df.describe()
# Out:
#        PassengerId    Survived      Pclass  ...       SibSp       Parch        Fare
# count   891.000000  891.000000  891.000000  ...  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642  ...    0.523008    0.381594   32.204208
# std     257.353842    0.486592    0.836071  ...    1.102743    0.806057   49.693429
# min       1.000000    0.000000    1.000000  ...    0.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000  ...    0.000000    0.000000    7.910400
# 50%     446.000000    0.000000    3.000000  ...    0.000000    0.000000   14.454200
# 75%     668.500000    1.000000    3.000000  ...    1.000000    0.000000   31.000000
# max     891.000000    1.000000    3.000000  ...    8.000000    6.000000  512.329200
#
# [8 rows x 7 columns]

# %% [markdown]
#  - Find all columns that have unique values. (example : the Gender column has 2 unique values Male and Female) <br>
#
#  - if the columns have finite unique values, then add them in a dictionary of lists and print it <br>
# <br>
# dictionary should look like : <br>
# <t>{<br>&nbsp;&nbsp; "Gender" : ["Male", "Female"],<br>&nbsp;&nbsp; "Col2" : ["unique1", "unique2"],<br>&nbsp;&nbsp;&nbsp;&nbsp;.<br>&nbsp;&nbsp;&nbsp;&nbsp;.<br>&nbsp;&nbsp;&nbsp;&nbsp;.<br>}

# %%
#write code here
dictionary={}
c=0
col1=list(train_df)#column names in a list
for col2 in train_df.columns:#col1, col2 go together
  uni=list(train_df[col2].unique())#check for unique in columns, make a list
  if len(uni)<20:#not to take names
    dictionary[col1[c]]=uni
  c+=1 #counter
for col,value in dictionary.items():
  print(col, ":",value)
# Out:
# Survived : [0, 1]
# Pclass : [3, 1, 2]
# Sex : ['male', 'female']
# SibSp : [1, 0, 3, 4, 2, 5, 8]
# Parch : [0, 1, 2, 5, 3, 4, 6]
# Embarked : ['S', 'C', 'Q', nan]

# %% [markdown]
# ### 3.b. Visualizing hidden Details

# %% [markdown]
# ##### Aim is to find relationship between Title and Survival rate
# - print the <b>name</b> column of the data<br>
# - notice that the word after the first comma encapsulates the title of the person (Mr., Mrs, etc)
# - extract the title using regular expression (help given below in the code)
# - store the title in a new column in the dataframe. Name the column : <b>Title</b>

# %%
import re
print(train_df.Name)
titleArr=[];
for name in train_df.Name:
   title_search = re.search('(\w+)\.', name) #the first argument is a pattern that we are looking for
#print("result:", title_search) #this is the result we get after looking for the pattern
   if title_search:
  #print("pattern found") #pattern found printed if a pattern like above is found
     title = title_search.group(1) #extracting the pattern found by regular expression (title here)
     titleArr.append(title)
train_df.insert(2,'Title',titleArr, True)
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
#regex example
import re

name_eg = "Petranec, Miss. Matilda"
title_search = re.search('(\w+)\.', name_eg) #the first argument is a pattern that we are looking for
print("result:", title_search) #this is the result we get after looking for the pattern
if title_search:
  print("pattern found") #pattern found printed if a pattern like above is found
  title = title_search.group(1) #extracting the pattern found by regular expression (title here)
  print("title:", title)
# Out:
# result: <re.Match object; span=(10, 15), match='Miss.'>
# pattern found
# title: Miss

# %%
#show the new dataframe with "Title" column here

# %%
print(train_df)
# Out:
#      PassengerId  Survived Title  ...     Fare Cabin Embarked
# 0              1         0    Mr  ...   7.2500   NaN        S
# 1              2         1   Mrs  ...  71.2833   C85        C
# 2              3         1  Miss  ...   7.9250   NaN        S
# 3              4         1   Mrs  ...  53.1000  C123        S
# 4              5         0    Mr  ...   8.0500   NaN        S
# ..           ...       ...   ...  ...      ...   ...      ...
# 886          887         0   Rev  ...  13.0000   NaN        S
# 887          888         1  Miss  ...  30.0000   B42        S
# 888          889         0  Miss  ...  23.4500   NaN        S
# 889          890         1    Mr  ...  30.0000  C148        C
# 890          891         0    Mr  ...   7.7500   NaN        Q
#
# [891 rows x 13 columns]

# %% [markdown]
# - write code to get unique values from the title column
# - use the unique titles to find the number of people who survived (1) and number of people who did not (0) for each title. <b>num_survived/total</b> will give the survival rate for that title
# - make a new dataframe called <b>SR_df</b> and add the survival rates corresponding to titles in it<br><br>
# you may write a function for the above.<br><br>
# expected output : <br>
# Mr &nbsp;&nbsp; 0.679392<br>
# Capt &nbsp;&nbsp; 0.1245<br>
# &nbsp;&nbsp;.<br>
# &nbsp;&nbsp;.<br>
# &nbsp;&nbsp;.<br>

# %%
#write code here
d={}
titleUni=train_df['Title'].unique()#all uniques in title
print(titleUni)


sur = 0
for i in titleUni :
  count=k=0
  sur =0
  for j in train_df['Title']:
    if j==i :
      count +=1
      if train_df.at[k,"Survived"]==1:
        sur+=1
    k+=1
  d[i]= sur/count
  
for col, value in d.items():
  print(col, ":", value)
# Out:
# ['Mr' 'Mrs' 'Miss' 'Master' 'Don' 'Rev' 'Dr' 'Mme' 'Ms' 'Major' 'Lady'
#  'Sir' 'Mlle' 'Col' 'Capt' 'Countess' 'Jonkheer']
# Mr : 0.15667311411992263
# Mrs : 0.792
# Miss : 0.6978021978021978
# Master : 0.575
# Don : 0.0
# Rev : 0.0
# Dr : 0.42857142857142855
# Mme : 1.0
# Ms : 1.0
# Major : 0.5
# Lady : 1.0
# Sir : 1.0
# Mlle : 1.0
# Col : 0.5
# Capt : 0.0
# Countess : 1.0
# Jonkheer : 0.0

# %%
#show the new dataframe SR_df here

# %%
SR_df = pd.DataFrame(list(d.items()),columns = ['Title','Survival Rate'])
SR_df
# Out:
#        Title  Survival Rate
# 0         Mr       0.156673
# 1        Mrs       0.792000
# 2       Miss       0.697802
# 3     Master       0.575000
# 4        Don       0.000000
# 5        Rev       0.000000
# 6         Dr       0.428571
# 7        Mme       1.000000
# 8         Ms       1.000000
# 9      Major       0.500000
# 10      Lady       1.000000
# 11       Sir       1.000000
# 12      Mlle       1.000000
# 13       Col       0.500000
# 14      Capt       0.000000
# 15  Countess       1.000000
# 16  Jonkheer       0.000000

# %% [markdown]
# - use SR_df to plot a bar graph for survival rate vs Title

# %%
#write code here

# %% [markdown]
# This brings us to the end of EDA. <br>
# You may feel free to do more exploratry analysis.<br>
# The aim of this notebook is not to point out every small detail but to give you an overview and guide you

# %%
SR_df.plot(x ='Title', y='Survival Rate', kind = 'bar')

# %% [markdown]
# ## 4. Data Visualization

# %% [markdown]
# - Make a pie chart to show the number of people who survived and number of people who did not
# - Make a pie chart to show the number of <b>Males</b> who survived and number of people who did not
# - Make a pie chart to show the number of <b>Females</b> who survived and number of people who did not
# <br><br>
# Note that all three charts must be visible in a single row (look into subplots)

# %%
#write code here
#write code here
t_sur = t_nsur = 0
m_sur = m_nsur = 0
f_sur = f_nsur = 0

total = []
males = []
females = []

j = 0
for i in train_df['Survived']:
  if i == 1:
    t_sur += 1
    if train_df.at[j, 'Sex'] == "male":
      m_sur += 1
    else:
      f_sur += 1

  else:
    t_nsur += 1
    if train_df.at[j, 'Sex'] == "male":
      m_nsur += 1
    else:
      f_nsur += 1
  j += 1

total.append(t_sur)
males.append(m_sur)
females.append(f_sur)

total.append(t_nsur)
males.append(m_nsur)
females.append(f_nsur)

plt.subplot(1,10,1)
plt.pie(total, radius=5, startangle=60, labels=["Survived", "Dead"], autopct = '%.1f%%')
plt.subplot(1,10,5)
plt.pie(male, radius=5, startangle=60, labels=["Male", "Female"], autopct = '%.1f%%')
plt.subplot(1,10,10)
plt.pie(female, radius=5, startangle=60, labels=["Male", "Female"], autopct = '%.1f%%')

plt.show()

# %% [markdown]
# - Find if money affected survival rate (fare and Pclass)
#  - Make a bar graph showing Pclass vs survival rate
#  - Make a KDE plot (use the sns library) and plot Fare based on the Survival (google away for this one)

# %%
#write code here
pclass_uni = train_df.Pclass.unique()
pclass_uni.sort()
di = {}
rows = len(train_df['Pclass'])

alive = dead = 0
for i in range (len(pclass_uni)):
  for j in range (rows):
    if train_df.at[j,'Pclass'] == pclass_uni[i]:
      if train_df.at[j,'Survived'] == 1:
        alive += 1
      else:
        dead +=1
      num = alive/(alive + dead)
      di[pclass_uni[i]] = num

SR_df = pd.DataFrame(list(di.items()),columns = ['Pclass','Survival Rate'])
SR_df.plot(x ='Pclass', y='Survival Rate', kind = 'bar')

# %%
figure, fare = plt.subplots(figsize=(6, 4.5))

sns.kdeplot(data=train_df.loc[(train_df['Survived'] == 0),'Fare'], color="Blue", shade=True, legend=True)
sns.kdeplot(data=train_df.loc[(train_df['Survived'] == 1),'Fare'], color="Orange", shade=True, legend=True)

fare.set_xlabel("Fare")
fare.set_ylabel("Density")
fare.legend(["0", "1"],title = "Survived", loc='upper right')

# %% [markdown]
# ## 5. Preprocessing
# preprocessing is a very important step before we step into modelling

# %% [markdown]
#  - when we added the Title column in the datadframe, we did preprocessing on the existing data to extract relevant information. As we also tried to explore and understand the data using survival rate, we saw it under EDA.

# %% [markdown]
# ### 5.a. Removing unnecessary columns

# %% [markdown]
#  - The columns PassengerId and Ticket play no logical role in being related to the survival of a passenger. Hence we will remove them.
#  - We will also remove the Name column as we have done <b>feature extraction</b> and obtained titles instead. (test set might have extra titles which are not in the train set. Think about how we would consider them. This however doesn't affect task 1's objective)

# %%
#write code to remove unnecessary columns from the dataframe here

# %%
train_df.drop(['PassengerId', 'Ticket', 'Name'], axis = 1, inplace = True)
train_df
# Out:
#      Survived Title  Pclass     Sex   Age  SibSp  Parch     Fare Cabin Embarked
# 0           0    Mr       3    male  22.0      1      0   7.2500   NaN        S
# 1           1   Mrs       1  female  38.0      1      0  71.2833   C85        C
# 2           1  Miss       3  female  26.0      0      0   7.9250   NaN        S
# 3           1   Mrs       1  female  35.0      1      0  53.1000  C123        S
# 4           0    Mr       3    male  35.0      0      0   8.0500   NaN        S
# ..        ...   ...     ...     ...   ...    ...    ...      ...   ...      ...
# 886         0   Rev       2    male  27.0      0      0  13.0000   NaN        S
# 887         1  Miss       1  female  19.0      0      0  30.0000   B42        S
# 888         0  Miss       3  female   NaN      1      2  23.4500   NaN        S
# 889         1    Mr       1    male  26.0      0      0  30.0000  C148        C
# 890         0    Mr       3    male  32.0      0      0   7.7500   NaN        Q
#
# [891 rows x 10 columns]

# %% [markdown]
# ### 5.b. Nan analysis

# %% [markdown]
#  - write code to find the percentage of Nans in each column and visualize it in a tabular format

# %%
#write code here
col1 = train_df.columns
value = []

for col2 in col1:
  x = train_df[col2].isna().sum()
  perc = (x/len(train_df))*100
  value.append(perc)
dic = dict(zip(col1, value))

table_df = pd.DataFrame(list(dic.items()),columns = ['Column','NAN Percentage'])
table_df
# Out:
#      Column  NAN Percentage
# 0  Survived        0.000000
# 1     Title        0.000000
# 2    Pclass        0.000000
# 3       Sex        0.000000
# 4       Age       19.865320
# 5     SibSp        0.000000
# 6     Parch        0.000000
# 7      Fare        0.000000
# 8     Cabin       77.104377
# 9  Embarked        0.224467

# %% [markdown]
#  - remove any column having more than 50% Nans as they would be of no use

# %%
#write code here
for i in range(len(table_df)):
  if table_df.at[i, 'NAN Percentage'] > 50:
    train_df.drop(col1[i], axis = 1, inplace=True)

# %% [markdown]
#  - Fill Nans in the Embark column with the statistical mode
#  - Fill Nans in the Age column with it's statistical mean

# %%
#write code here
train_df['Embarked'].fillna(train_df['Embarked'].mode()[0], inplace=True)
avg=train_df["Age"].mean()
train_df["Age"].fillna(avg, inplace=True)
print(train_df)
# Out:
#      Survived Title  Pclass     Sex        Age  SibSp  Parch     Fare Embarked
# 0           0    Mr       3    male  22.000000      1      0   7.2500        S
# 1           1   Mrs       1  female  38.000000      1      0  71.2833        C
# 2           1  Miss       3  female  26.000000      0      0   7.9250        S
# 3           1   Mrs       1  female  35.000000      1      0  53.1000        S
# 4           0    Mr       3    male  35.000000      0      0   8.0500        S
# ..        ...   ...     ...     ...        ...    ...    ...      ...      ...
# 886         0   Rev       2    male  27.000000      0      0  13.0000        S
# 887         1  Miss       1  female  19.000000      0      0  30.0000        S
# 888         0  Miss       3  female  29.699118      1      2  23.4500        S
# 889         1    Mr       1    male  26.000000      0      0  30.0000        C
# 890         0    Mr       3    male  32.000000      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %% [markdown]
#  - show the new Nan percentage vs column name table after filling and removing to make sure there are no Nans

# %%
#write code here

# %%
col1 = train_df.columns
value = []

for col2 in col1:
  x = train_df[col2].isna().sum()
  perc = (x/len(train_df))*100
  value.append(perc)
dic = dict(zip(col1, value))

table_df = pd.DataFrame(list(dic.items()),columns = ['Column','NAN Percentage'])
table_df
# Out:
#      Column  NAN Percentage
# 0  Survived             0.0
# 1     Title             0.0
# 2    Pclass             0.0
# 3       Sex             0.0
# 4       Age             0.0
# 5     SibSp             0.0
# 6     Parch             0.0
# 7      Fare             0.0
# 8  Embarked             0.0

# %% [markdown]
# ### 5.c. Adding features to the dataset

# %% [markdown]
#  - Read the kaggle link (titanic dataset) provided above and see what the two columns SibSP and Parch signify
#  - Using that create a new column called <B>Family_members</b>
#  - Fill it with the sum of SibSP and Parch

# %%
#write code here
sum2 = train_df['SibSp'] + train_df['Parch']
train_df["Family_members"] = sum2

# %% [markdown]
#  - Now you may remove the two columns SibSP and Parch<br>
#  It is important to remove them because they introduce multicollinearity in our dataset now as the new column Family_members is directly dependent on them.<br>
#  Multicollinearity is deadly to linear models that we will look into later

# %%
#write code here

# %%
train_df.drop(['SibSp', 'Parch'], axis = 1, inplace = True)

# %% [markdown]
# ### 5.d. Scaling and Normalization
# we don't want to give undue advantage to a few columns (when training models), just because they have a numeric data that is larger in magnitude.<br>
# Therefore we scale all values down to a specific range or distribution
# <br>

# %% [markdown]
#  - Columns to apply scaling on
#   - Age
#   - Fare
#   - Family_members
#
# - Although Pclass column is numeric, it contains classification data (only 1, 2 and 3). Therefore only continuous data like age, fare, etc needs to be normalized

# %% [markdown]
#  - Read about standardization and normalization in this link https://www.geeksforgeeks.org/normalization-vs-standardization/
#  - apply the formulas given in the link above and scale/normalize the features that are supposed to be scaled
#  - It is your choice to choose wether you choose to normalize or standardize a column. You will be able to make your choice after reading the link contents.
#  - If you feel confused with the choice, then you can go ahead and directly normalize.

# %%
#write code here to normalize data

# %%
def normal(take):
  X_new=[]
  X_max = max(take)
  X_min = min(take)
  for i in take:
    X_new.append((i-X_min)/(X_max-X_min))
  return X_new


train_df['Age']=normal(train_df['Age'])
train_df['Fare']=normal(train_df['Fare'])
train_df['Family_members']=normal(train_df['Family_members'])

# %% [markdown]
# ### 5.e. One hot encoding
# Machine Learning models do not understand strings <br>
# They understand numbers<br>
# That is one of the reasons why we one hot encode few columns<br>
#
# - refer this link for more information : https://datagy.io/pandas-get-dummies/
# - you can use this or directly look into pandas get_dummies() method to implement this

# %% [markdown]
# - columns to apply one_hot encoding on
#  - Pclass
#  - Sex
#  - Title
#  - Embarked

# %%
#write code here
dummy_pclass = (pd.get_dummies(train_df['Pclass']))
for col in dummy_pclass:
    temp = dummy_pclass[col]
    train_df = train_df.join(temp)
dummy_sex = pd.get_dummies(train_df['Sex'])
for col in dummy_sex:
    temp = dummy_sex[col]
    train_df = train_df.join(temp)
dummy_title = pd.get_dummies(train_df['Title'])
for col in dummy_title:
    temp = dummy_title[col]
    train_df = train_df.join(temp)
dummy_embarked = pd.get_dummies(train_df['Embarked'])
for col in dummy_embarked:
    temp = dummy_embarked[col]
    train_df = train_df.join(temp)

# %%
#show the final dataframe here
train_df
# Out:
#      Survived Title  Pclass     Sex       Age      Fare  ... Ms  Rev  Sir  C  Q  S
# 0           0    Mr       3    male  0.271174  0.014151  ...  0    0    0  0  0  1
# 1           1   Mrs       1  female  0.472229  0.139136  ...  0    0    0  1  0  0
# 2           1  Miss       3  female  0.321438  0.015469  ...  0    0    0  0  0  1
# 3           1   Mrs       1  female  0.434531  0.103644  ...  0    0    0  0  0  1
# 4           0    Mr       3    male  0.434531  0.015713  ...  0    0    0  0  0  1
# ..        ...   ...     ...     ...       ...       ...  ... ..  ...  ... .. .. ..
# 886         0   Rev       2    male  0.334004  0.025374  ...  0    1    0  0  0  1
# 887         1  Miss       1  female  0.233476  0.058556  ...  0    0    0  0  0  1
# 888         0  Miss       3  female  0.367921  0.045771  ...  0    0    0  0  0  1
# 889         1    Mr       1    male  0.321438  0.058556  ...  0    0    0  1  0  0
# 890         0    Mr       3    male  0.396833  0.015127  ...  0    0    0  0  1  0
#
# [891 rows x 33 columns]

# %% [markdown]
# End of Preprocessing
